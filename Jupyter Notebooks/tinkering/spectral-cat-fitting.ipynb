# %%
from gdt.core import data_path
from gdt.missions.fermi.gbm.scat import Scat
filepath = 'data/glg_scat_all_bn160118060_flnc_comp_v01.fit'

scat = Scat.open(filepath)

# %%
scat.model_fits
# Out:
# [<GbmModelFit: Comptonized, Epeak>]

# %%
one_fit = scat.model_fits[0]
one_fit.time_range
# Out:
# (np.float64(-1.024), np.float64(53.248))

# %%
one_fit.stat_name
# Out:
# 'Castor C-STAT'

# %%
one_fit.stat_value
# Out:
# 637.5641479492188

# %%
one_fit.dof
# Out:
# 360

# %%
one_fit.name
# Out:
# 'Comptonized, Epeak'

# %%
one_fit.parameter_list()
# Out:
# ['Amplitude', 'Epeak', 'Index', 'Pivot E =fix']

# %%
print(one_fit)
# Out:
# Comptonized, Epeak
#    Amplitude: 1.93e-02 +7.57e-04/-7.07e-04
#    Epeak: 253.07 +9.45/-8.92
#    Index: -8.58e-01 +3.03e-02/-2.94e-02
#    Pivot E =fix: 1.00e+02 +/- 0.00e+00

# %%
scat.detectors[1]
# Out:
# <GbmDetectorData: NAI_04; TTE;
#  time range: (-1.024, 53.248) s;
#  energy range: (7.964, 899.28) keV>
